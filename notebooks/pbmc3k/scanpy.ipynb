# %%
import scanpy as sc
import pandas as pd

# %% [markdown]
# # Pipelines for PBMC3k
#
# ## loading h5ad -> quality control -> filtering -> normalizing -> scale -> highly variable genes -> pca -> umap -> DE

# %%
adata = sc.read_10x_mtx(
    "data/",
    var_names="gene_symbols",
    cache=False
)

adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %%
adata.var[
